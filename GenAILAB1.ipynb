# %% [markdown]
# <a href="https://colab.research.google.com/github/sharanyamp24-design/Severity_Prediction-/blob/main/GenAILAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Day1 Project

# %%
#downloading synthetic Medical Triage Priority Dataset from Kaggle into #content/data/raw

# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-90c93861-7caf-43f9-bdb7-168a4a8b50e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90c93861-7caf-43f9-bdb7-168a4a8b50e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !mkdir -p /content/data/raw

# %%
# !kaggle datasets download -d azam897/synapse-dataset-of-symptoms-and-demographics -p /content/data/raw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/azam897/synapse-dataset-of-symptoms-and-demographics
# License(s): apache-2.0
# ...
# 100% 627k/627k [00:01<00:00, 608kB/s]

# %%
# !unzip /content/data/raw/*.zip -d /content/data/raw
# Out:
# Archive:  /content/data/raw/synapse-dataset-of-symptoms-and-demographics.zip
#   inflating: /content/data/raw/SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv

# %%
# !ls /content/data/raw
# Out:
# 'SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv'
#  synapse-dataset-of-symptoms-and-demographics.zip

# %%
import pandas as pd

df = pd.read_csv('/content/data/raw/Synapse_Dataset.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5294/1834563876.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/data/raw/Synapse_Dataset.csv')
#       4 df.head()
#
# ...

# %%
# !ls /content/data/raw
# Out:
# 'SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv'
#  synapse-dataset-of-symptoms-and-demographics.zip

# %%
import os
os.listdir('/content/data/raw')
# Out:
# ['synapse-dataset-of-symptoms-and-demographics.zip',
#  'SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv']

# %%
import pandas as pd

df = pd.read_csv('/content/data/raw/SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv')
df.head()
# Out:
#                                             Symptoms  Gender             Age  \
# 0  Unwanted weight loss, Mouth sore, Persistent m...    Male      6-15 years
# 1  Feeling tired, Shortness breath, Blue skin col...  Female   below 5 years
# 2  False beliefs, Seeing, hearing things are not ...    Male      6-15 years
# 3  Chest pain, Shortness breath, Fast heart rate,...  Female  above 45 years
# 4  fever, vaginal bleeding, painful urination, di...  Female   below 5 years
#
#               Duration  Severity Final Recommendation
# 0  Greater than 3 days    Severe  Doctor Consultation
# 1  Greater than 3 days    Severe  Doctor Consultation
# 2  Greater than 3 days      Mild  Doctor Consultation
# 3  Greater than 3 days  Moderate  Doctor Consultation
# 4     Less than 3 days    Severe  Doctor Consultation

# %%
# !ls /content/data/raw
# Out:
# 'SYNAPSE_An Expert Annotated Dataset of Patient symptoms and Demographics.csv'
#  synapse-dataset-of-symptoms-and-demographics.zip

# %%
df.shape
# Out:
# (130637, 6)

# %% [markdown]
# # gg

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)
print("\nInfo:")
print(df.info())
print("\nMissing Values:\n", df.isnull().sum())
print("\nFirst 5 Rows:")
display(df.head())
# Out:
# Shape: (130637, 6)
#
# Columns:
#  Index(['Symptoms', 'Gender', 'Age', 'Duration', 'Severity',
#        'Final Recommendation'],
#       dtype='object')
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130637 entries, 0 to 130636
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Symptoms              130637 non-null  object
#  1   Gender                130637 non-null  object
#  2   Age                   130637 non-null  object
#  3   Duration              130637 non-null  object
#  4   Severity              130637 non-null  object
#  5   Final Recommendation  130637 non-null  object
# dtypes: object(6)
# memory usage: 6.0+ MB
# None
#
# Missing Values:
#  Symptoms                0
# Gender                  0
# Age                     0
# Duration                0
# Severity                0
# Final Recommendation    0
# dtype: int64
#
# First 5 Rows:
# ...

# %%
import os

# Create train folder
os.makedirs('/content/train', exist_ok=True)

# Extract first 10,000 rows
train_df = df.head(10000)

# Save as CSV
train_df.to_csv('/content/train/full_data.csv', index=False)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
# !ls /content/train
# Out:
# full_data.csv

# %%
check_df = pd.read_csv('/content/train/full_data.csv')
check_df.shape
# Out:
# (10000, 6)

# %%
import os

# Create test folder
os.makedirs('/content/test', exist_ok=True)

# Extract first 2,000 rows
test_df = df.head(2000)

# Save as CSV
test_df.to_csv('/content/test/test_data.csv', index=False)

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
# !ls /content/test
# Out:
# test_data.csv

# %%
check_df = pd.read_csv('/content/test/test_data.csv')
check_df.shape
# Out:
# (2000, 6)

# %%
import pandas as pd

# Load test dataset
test_df = pd.read_csv('/content/test/test_data.csv')

# Remove severity column
test_df = test_df.drop(columns=['severity'])

# Save updated file
test_df.to_csv('/content/test/test_data.csv', index=False)

print("severity column removed successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5294/3512426704.py in <cell line: 0>()
#       5
#       6 # Remove severity column
# ----> 7 test_df = test_df.drop(columns=['severity'])
#       8
#       9 # Save updated file
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
# Remove column containing 'severity'
test_df = test_df.drop(
    columns=[col for col in test_df.columns if col.strip().lower() == 'severity']
)

# Save updated file
test_df.to_csv('/content/test/test_data.csv', index=False)

print("Severity column removed successfully!")
# Out:
# Severity column removed successfully!

# %%
test_df.columns
# Out:
# Index(['Symptoms', 'Gender', 'Age', 'Duration', 'Final Recommendation'], dtype='object')
